# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeswariesamsetti/FMML-LABS-/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-17 16:12:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   239MB/s    in 0.3s
#
# 2025-03-17 16:12:02 (239 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22735  1705.07642v1  We study unsupervised generative modeling in t...  stat
# 30207  1711.09017v1  Learning-based methods are believed to work we...    cs
# 18132  cs/0405049v1  The academic literature suggests that the exte...    cs
# 36142   1207.1365v1  It is well known that there may be many causal...  stat
# 1613   1606.03777v2  One of the core components of modern spoken di...    cs
# ...             ...                                                ...   ...
# 3761   1705.05116v1  This paper introduces an end-to-end fine-tunin...    cs
# 22237  1509.06831v1  Given i.i.d samples from some unknown continuo...  stat
# 20565  1606.09140v3  A qualitative representation $\phi$ is like an...    cs
# 26897  1701.02273v3  In multi-object tracking applications, model p...    cs
# 7807   1803.05045v1  Generative adversarial networks are used to ge...  stat
#
#                                                    title  year  \
# 22735  From optimal transport to generative modeling:...  2017
# 30207  MPIIGaze: Real-World Dataset and Deep Appearan...  2017
# 18132     Export Behaviour Modeling Using EvoNF Approach  2004
# 36142  Towards Characterizing Markov Equivalence Clas...  2012
# 1613   Neural Belief Tracker: Data-Driven Dialogue St...  2016
# ...                                                  ...   ...
# 3761   Tuning Modular Networks with Weighted Losses f...  2017
# 22237                 Density Estimation via Discrepancy  2015
# 20565  Algebraic foundations for qualitative calculi ...  2016
# 26897  Visual Multiple-Object Tracking for Unknown Cl...  2017
# 7807       Analysis of Nonautonomous Adversarial Systems  2018
#
#                                                 keywords
# 22735  [unsupervised, generative, transport, distribu...
# 30207  [unconstrained, estimation, estimation, monocu...
# 18132  [literature, exporting, multinational, corpora...
# 36142  [explanations, consistent, represent, explanat...
# 1613   [components, estimates, approaches, difficulty...
# ...                                                  ...
# 3761   [introduces, coordination, independently, bene...
# 22237  [continuous, rectangle, piecewise, approximate...
# 20565  [qualitative, representation, representation, ...
# 26897  [applications, parameter, prerequisite, perfor...
# 7807   [generative, adversarial, convergence, propert...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22735    [unsupervised, generative, transport, distribu...
# 30207    [unconstrained, estimation, estimation, monocu...
# 18132    [literature, exporting, multinational, corpora...
# 36142    [explanations, consistent, represent, explanat...
# 1613     [components, estimates, approaches, difficulty...
#                                ...
# 25735    [categories, recognition, increasingly, suffic...
# 8928     [sequential, constraint, extensions, connectio...
# 7815     [distributed, attracted, attention, especially...
# 13664    [biological, populations, collaboratively, pop...
# 1730     [generative, interaction, evolution, discovers...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8752 words.
# Out of those 4552 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b48dae60-2b14-40d7-ac8d-f997ab7647d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b48dae60-2b14-40d7-ac8d-f997ab7647d2")) {                    Plotly.newPlot(                        "b48dae60-2b14-40d7-ac8d-f997ab7647d2",                        [{"x":["adversarial","distribution","minimized","heuristically","establishing","objective","justification","understanding","theoretical","transport","techniques","stochastic","equivalently","variational","optimization","wasserstein","efficiently","probabilistic","constrained","penalized","posterior","unsupervised","generated","distributions","generative","coincides","evaluations","realistic","conditions","unconstrained","addressing","limitations","resolution","positions","contributions","corresponding","performance","estimation","evaluated","including","facilitate","extensive","continuous","annotated","experience","information","assumptions","illumination","evaluation","laboratory","monocular","environment","collected","variation","challenges","challenging","regarding","appearance","informative","reasonable","behaviour","resources","multinational","empirical","optimised","computation","corporation","inference","financial","evolutionary","literature","determine","independence","manufactured","protection","relationship","suppliers","customers","consistent","construct","equivalence","relations","orientation","explanations","ancestral","represent","representation","conditional","representative","essential","selection","variables","characterizing","explanation","relationships","capturing","overcomes","linguistic","distributed","outperforming","framework","approaches","estimates","utterances","dependency","difficulty","surpasses","components","representations","combination","justifying","subspaces","parameter","algorithm","underlying","clustering","curvature","concentrated","strategies","practically","probability","interaction","foundations","different","answering","classical","automatic","automatically","designing","questions","similarity","processing","faithfulness","translation","specifically","alignment","sentences","adjustment","bidirectional","languages","maximizes","descriptions","terminology","partially","background","investigated","difficult","acquisition","implementation","particular","exploration","providing","algorithmic","described","axiomatic","attribute","transparent","knowledge","consistency","factorization","simulated","symmetric","communities","membership","factorizations","computationally","demonstrate","memberships","attention","parameters","sufficient","guarantee","blockmodel","nonnegative","overlapping","efficient","proposing","previously","methodology","classification","discriminative","processes","regression","dimensional","functions","multivariate","recognition","convolved","investigation","beginning","qualitative","benchmarking","significantly","commercial","pipelines","methodologies","platforms","comparative","absolutely","conference"],"y":[92,227,12,3,23,152,9,161,166,5,391,139,5,48,318,8,154,149,55,5,44,153,155,108,116,1,61,52,123,23,27,62,128,25,37,137,866,225,141,266,26,182,101,85,42,733,76,43,245,8,20,123,75,55,127,259,49,75,38,40,32,62,1,154,6,131,3,222,8,56,123,78,29,2,13,68,2,10,90,86,20,86,23,19,0,123,371,105,35,70,179,110,16,20,62,40,9,61,82,20,522,444,84,13,45,47,7,108,200,116,3,20,111,802,122,148,13,2,89,14,145,90,13,741,57,97,171,165,42,71,142,270,4,113,164,49,80,14,25,97,15,37,9,49,81,42,143,37,104,259,63,101,48,69,5,34,14,372,59,38,71,28,14,13,3,93,543,4,174,246,67,37,1,6,21,387,14,99,81,501,110,102,126,186,206,24,357,2,34,11,60,11,225,25,11,19,29,37,5,11],"type":"bar"},{"x":["adversarial","distribution","minimized","heuristically","establ ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4552,), (4552, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Deep</span> <span style=''>Belief</span> <span style=''>Network</span> <span style=''>Based</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>System</span> <span style=''>for</span> <span style=''>Risky</span> <span style=''>Host</span> <span style='background-color:rgba(0, 255, 0, 0.5350877192982457);'>Detection</span> <br/><br/><span style=''>To</span> <span style=''>assure</span> <span style=''>cyber</span> <span style=''>security</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>enterprise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>SIEM</span> <span style=''>(Security</span> <span style='background-color:rgba(0, 255, 0, 0.3339399454049136);'>Information</span> <span style=''>and</span> <span style=''>Event</span> <span style=''>Management)</span> <span style=''>system</span> <span style=''>is</span> <span style=''>in</span> <span style=''>place</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>normalize</span> <span style=''>security</span> <span style=''>event</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.31967943009795197);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preventive</span> <span style='background-color:rgba(0, 255, 0, 0.8378378378378379);'>technologies</span> <span style=''>and</span> <span style=''>flag</span> <span style=''>alerts</span> <span style=''>Analysts</span> <span style=''>in</span> <span style=''>the</span> <span style=''>security</span> <span style='background-color:rgba(0, 255, 0, 0.4576271186440679);'>operation</span> <span style=''>center</span> <span style=''>(SOC)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>alerts</span> <span style=''>to</span> <span style=''>decide</span> <span style=''>if</span> <span style=''>it</span> <span style=''>is</span> <span style=''>truly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>malicious</span> <span style=''>or</span> <span style=''>not</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>alerts</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>overwhelming</span> <span style=''>with</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>them</span> <span style=''>being</span> <span style=''>false</span> <span style=''>positive</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exceeding</span> <span style=''>the</span> <span style=''>SOCs</span> <span style=''>capacity</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>all</span> <span style=''>alerts</span> <span style=''>There</span> <span style=''>is</span> <span style=''>a</span> <span style=''>great</span> <span style=''>need</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>false</span> <span style=''>positive</span> <span style=''>rate</span> <span style=''>as</span> <span style=''>much</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>While</span> <span style=''>most</span> <span style=''>previous</span> <span style=''>research</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666666);'>intrusion</span> <span style='background-color:rgba(0, 255, 0, 0.5350877192982457);'>detection</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.5350877192982457);'>detection</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>mlrMBO</span> <span style=''>A</span> <span style=''>Modular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style=''>Model</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Expensive</span> <span style=''>Black</span> <span style=''>Box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>mlrMBO</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprehensive</span> <span style=''>R</span> <span style=''>toolbox</span> <span style=''>for</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>(MBO)</span> <span style=''>also</span> <span style=''>known</span> <span style=''>as</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>the</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>through</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>It</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>for</span> <span style=''>both</span> <span style=''>single</span> <span style=''>and</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>mixed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>categorical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Additional</span> <span style=''>features</span> <span style=''>include</span> <span style=''>multi</span> <span style=''>point</span> <span style=''>batch</span> <span style=''>proposal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parallelization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>visualization</span> <span style=''>logging</span> <span style=''>and</span> <span style=''>error</span> <span style=''>handling</span> <span style=''>mlrMBO</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>in</span> <span style=''>a</span> <span style=''>modular</span> <span style=''>fashion</span> <span style=''>such</span> <span style=''>that</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>replaced</span> <span style=''>or</span> <span style=''>adapted</span> <span style=''>by</span> <span style=''>the</span> <span style=''>user</span> <span style=''>for</span> <span style=''>specific</span> <span style=''>use</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style=''>beats</span> <span style='background-color:rgba(255, 0, 0, 0.5294117647058822);'>concentration</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>view</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>with</span> <span style=''>smooth</span> <span style=''>radial</span> <span style=''>kernels</span> <br/><br/><span style=''>Positive</span> <span style=''>definite</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style='background-color:rgba(255, 0, 0, 0.7454545454545454);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Spaces</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematically</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>compelling</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>from</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>take</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>theory</span> <span style=''>point</span> <span style=''>of</span> <span style=''>view</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>various</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>smooth</span> <span style=''>kernels</span> <span style=''>related</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inferential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>We</span> <span style=''>analyze</span> <span style='background-color:rgba(255, 0, 0, 0.6923076923076923);'>eigenvalue</span> <span style=''>decay</span> <span style=''>of</span> <span style=''>kernels</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operators</span> <span style=''>and</span> <span style=''>matrices</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>eigenfunctionseigenvectors</span> <span style=''>and</span> <span style=''>Fourier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coefficients</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>set</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>fitting</span> <span style=''>capacity</span> <span style=''>of</span> <span style=''>kernels</span> <span style=''>giving</span> <span style=''>explicit</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>fat</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>shattering</span> <span style='background-color:rgba(255, 0, 0, 0.3604060913705583);'>dimension</span> <span style=''>of</span> <span style=''>the</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimension</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Scheduling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Application</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Biological</span> <span style=''>Systems</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>(BO)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>method</span> <span style=''>for</span> <span style=''>global</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>fitness</span> <span style=''>function</span> <span style=''>BO</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>assumes</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>BO</span> <span style=''>is</span> <span style=''>cheap</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>are</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>or</span> <span style=''>costly</span> <span style=''>In</span> <span style=''>practice</span> <span style=''>this</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>ten</span> <span style=''>or</span> <span style=''>fewer</span> <span style=''>critical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>up</span> <span style=''>to</span> <span style=''>1000</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>But</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>may</span> <span style=''>be</span> <span style=''>less</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>than</span> <span style=''>BO</span> <span style=''>methods</span> <span style=''>assume</span> <span style=''>In</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulation</span> <span style=''>models</span> <span style=''>we</span> <span style=''>may</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style=''>conduct</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thousands</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>in</span> <span style=''>a</span> <span style=''>few</span> <span style=''>hours</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>burden</span> <span style=''>of</span> <span style=''>BO</span> <span style=''>is</span> <span style=''>no</span> <span style=''>longer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>negligible</span> <span style=''>compared</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimentation</span> <span style=''>time</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13541297412265155)
# 	architecture (0.08224034030485644)
# 	segmentation (0.06947890818858561)
# 	representation (0.1315136476426799)
# 	knowledge (0.13186813186813187)
# 	different (0.2626728110599078)
# 	detection (0.12406947890818859)
# 	information (0.2598369372562921)
# 	recognition (0.12655086848635236)
# 	convolutional (0.1336405529953917)
#
# Some Statistics words are:
# 	estimation (0.16826680141485598)
# 	algorithms (0.28600303183425974)
# 	theoretical (0.15159171298635674)
# 	statistical (0.15361293582617483)
# 	distribution (0.18595250126326426)
# 	variables (0.146033350176857)
# 	inference (0.19504800404244568)
# 	dimensional (0.1844365841334007)
# 	algorithm (0.4067710965133906)
# 	regression (0.1773623041940374)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="348c0dd0-0704-4361-8666-a056942ab689" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("348c0dd0-0704-4361-8666-a056942ab689")) {                    Plotly.newPlot(                        "348c0dd0-0704-4361-8666-a056942ab689",                        [{"x":["adversarial","distribution","minimized","heuristically","establishing","objective","justification","understanding","theoretical","transport","techniques","stochastic","equivalently","variational","optimization","wasserstein","efficiently","probabilistic","constrained","penalized","posterior","unsupervised","generated","distributions","generative","coincides","evaluations","realistic","conditions","unconstrained","addressing","limitations","resolution","positions","contributions","corresponding","performance","estimation","evaluated","including","facilitate","extensive","continuous","annotated","experience","information","assumptions","illumination","evaluation","laboratory","monocular","environment","collected","variation","challenges","challenging","regarding","appearance","informative","reasonable","behaviour","resources","multinational","empirical","optimised","computation","corporation","inference","financial","evolutionary","literature","determine","independence","manufactured","protection","relationship","suppliers","customers","consistent","construct","equivalence","relations","orientation","explanations","ancestral","represent","representation","conditional","representative","essential","selection","variables","characterizing","explanation","relationships","capturing","overcomes","linguistic","distributed","outperforming","framework","approaches","estimates","utterances","dependency","difficulty","surpasses","components","representations","combination","justifying","subspaces","parameter","algorithm","underlying","clustering","curvature","concentrated","strategies","practically","probability","interaction","foundations","different","answering","classical","automatic","automatically","designing","questions","similarity","processing","faithfulness","translation","specifically","alignment","sentences","adjustment","bidirectional","languages","maximizes","descriptions","terminology","partially","background","investigated","difficult","acquisition","implementation","particular","exploration","providing","algorithmic","described","axiomatic","attribute","transparent","knowledge","consistency","factorization","simulated","symmetric","communities","membership","factorizations","computationally","demonstrate","memberships","attention","parameters","sufficient","guarantee","blockmodel","nonnegative","overlapping","efficient","proposing","previously","methodology","classification","discriminative","processes","regression","dimensional","functions","multivariate","recognition","convolved","investigation","beginning","qualitative","benchmarking","significantly","commercial","pipelines","methodologies","platforms","comparative","absolutely","conference","integration","quantitatively","restricted","introduced","individual","comparing","visualizations","consumption","holistically","associated","overfitting","parametric","specified","available","explicitly","precludes","detection","challenge","discovery","formulation","implicitly","incorporate","uncertainty","scientific","structure","visualizing","appropriate","functional","estimating","noticeable","statistical","expressive","calibrated","nonparametric","candidate","introduce","definition","subjective","experimentally","uncertainties","certainty","arbitrary","annotations","supervised","effectiveness","structural","microsoft","grounding","consistently","complementarity","correspond","correspondence","structures","compositional ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	ancestral
# 	precludes
# 	collaborators
# 	depressive
# 	stabilisation
# 	rewritten
# 	pediatric
# 	modulating
# 	archetypal
# 	archetypes
# 	judiciously
# 	unequally
# 	autocorrelation
# 	increments
# 	searchlight
# 	procrustes
# 	subgaussian
# 	semiparametric
# 	interrelated
# 	unraveling
# Some words which never appear in Statistics papers:
# 	monocular
# 	suppliers
# 	absolutely
# 	certainty
# 	grounding
# 	complementarity
# 	residential
# 	residents
# 	reconstructs
# 	mirroring
# 	attentions
# 	professionals
# 	microscopes
# 	superfluous
# 	photography
# 	unemployment
# 	metalearning
# 	linearize
# 	disambiguation
# 	collisions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.052316708381662e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
